# %%
import botometer
import tweepy
import pandas as pd
import unicodedata
import re

# %%
consumer_key = 'VtrwjoxddfiAsXguhdJm76NM6'
consumer_secret = 'B5RQKNS3b7QGLwDzwcJeRbgIrtutQoVNHcBhZL1KFl7yepyObT'
access_token = '1071372097333542912-ak1cv74M7HykSiVTuQaO1pzJcPDS6W'
access_token_secret = '6Wg2iRn5LJTeX1MTDQ7iKdSLWKyXwm0hZ6bbuP52PiM80'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# rapidapi_key = "69ba76c6f1msh08f4419a225be26p1b541ejsnb2367cceaf31" # now it's called rapidapi key
rapidapi_key = "DISqJ3R5z77cWRS4ZFSjXV2uWgPGb2sg"
twitter_app_auth = {
    'consumer_key': 'VtrwjoxddfiAsXguhdJm76NM6',
    'consumer_secret': 'B5RQKNS3b7QGLwDzwcJeRbgIrtutQoVNHcBhZL1KFl7yepyObT',
    'access_token': '1071372097333542912-ak1cv74M7HykSiVTuQaO1pzJcPDS6W',
    'access_token_secret': '6Wg2iRn5LJTeX1MTDQ7iKdSLWKyXwm0hZ6bbuP52PiM80',
  }

# %%
user=[]
text=[]
rt_count=[]
fav_count=[]
loc=[]
created_at=[]
followers=[]
scores=[]

# %%
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
            user = status.user.screen_name
            text = status.text
            rt_count = status.retweet_count
            fav_count = status.favorite_count
            loc = status.user.location
            created_at = status.user.created_at
            follower=status.user.followers_count
            print(user)
            print(text)
#             print(rt_count)
#             print(fav_count)
#             print(loc)
            print(created_at)
#             print(followers)
            print()
            csvWriter.writerow([tweet.created_at, tw, tweet.retweet_count, tweet.favorite_count, user, tweet.user.name, tweet.user.location, tweet.user.geo_enabled, tweet.user.friends_count, tweet.user.followers_count, tweet.user.statuses_count, tweet.user.default_profile_image])
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_error disconnects the stream
            return False

# %%
import botometer

rapidapi_key = "DISqJ3R5z77cWRS4ZFSjXV2uWgPGb2sg"
twitter_app_auth = {
    'consumer_key': 'VtrwjoxddfiAsXguhdJm76NM6',
    'consumer_secret': 'B5RQKNS3b7QGLwDzwcJeRbgIrtutQoVNHcBhZL1KFl7yepyObT',
    'access_token': '1071372097333542912-ak1cv74M7HykSiVTuQaO1pzJcPDS6W',
    'access_token_secret': '6Wg2iRn5LJTeX1MTDQ7iKdSLWKyXwm0hZ6bbuP52PiM80',
  }
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# Check a single account by screen name
result = bom.check_account('@clayadavis')

# Check a single account by id
result = bom.check_account(1548959833)

# Check a sequence of accounts
# accounts = ['@clayadavis', '@onurvarol', '@jabawack']
# # for screen_name, result in bom.check_accounts_in(accounts):
#     # Do stuff with `screen_name` and `result`

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
import requests

url = "https://botometer-pro.p.rapidapi.com/2/check_account"

payload = "{  \"user\": {    \"id\": \"1234567890\",    \"screen_name\": \"IUNetSci\",    \"...\": \"...\"  },  \"timeline\": [    {      \"id\": 1234567890,      \"text\": \"@Botometer is so cool!\",      \"...\": \"...\"    },    \"...\"  ],  \"mentions\": [    {      \"id\": 9876543210,      \"text\": \"@TruthyAtIndiana is also cool!\",      \"...\": \"...\"    },    \"...\"  ]}"
headers = {
    'x-rapidapi-host': "botometer-pro.p.rapidapi.com",
    'x-rapidapi-key': "69ba76c6f1msh08f4419a225be26p1b541ejsnb2367cceaf31",
    'content-type': "application/json",
    'accept': "application/json"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {
#   "message": "Test request OK!",
#   "status": "test ok"
# }

# %%
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key, header=header,
                          **twitter_app_auth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b513c172e051> in <module>
#       1 bom = botometer.Botometer(wait_on_ratelimit=True,
# ----> 2                           rapidapi_key=rapidapi_key, header=header,
#       3                           **twitter_app_auth)
#
# NameError: name 'header' is not defined

# %%
myStream.filter(track=['corona', 'covid19'])
# Out:
# RTurketi
# RT @akbasogluemin: Güzel gidiyoruz, bu musibetten hep birlikte mücadele ederek kurtulacağız inşâAllah. Tedbirleri gevşetmeden uygulamaya de…
# 2018-04-18 07:55:38
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-71-872e74fe3849> in <module>
# ----> 1 myStream.filter(track=['corona', 'covid19'])
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# ...

# %%
bom = botometer.Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapidapi_key,
                          **twitter_app_auth)

# %%
# Check a single account by screen name
user = '@afarihas'
result = bom.check_account(user)
result
# Out:
# {'cap': {'english': 0.0012183789109573519, 'universal': 0.0020139366550120737},
#  'categories': {'content': 0.398120617474611,
#   'friend': 0.06497595221508463,
#   'network': 0.0933661140220537,
#   'sentiment': 0.6087972435240742,
#   'temporal': 0.0887777161089108,
#   'user': 0.04041078582876067},
#  'display_scores': {'content': 2.0,
#   'english': 0.1,
#   'friend': 0.3,
#   'network': 0.5,
#   'sentiment': 3.0,
#   'temporal': 0.4,
#   'universal': 0.2,
#   'user': 0.2},
#  'scores': {'english': 0.023437100509770627,
#   'universal': 0.037980136466376074},
#  'user': {'id_str': '715585963', 'screen_name': 'Afarihas'}}

# %%
bom.twitter_api.verify_credentials()
# Out:
# {'id': 1071372097333542912,
#  'id_str': '1071372097333542912',
#  'name': 'Siwi C',
#  'screen_name': 'SiwiC1',
#  'location': '',
#  'description': '',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 0,
#  'friends_count': 2,
#  'listed_count': 0,
#  'created_at': 'Sat Dec 08 11:53:07 +0000 2018',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 2,
#  'lang': None,
#  'status': {'created_at': 'Wed Jan 02 03:04:05 +0000 2019',
#   'id': 1080298656928952320,
#   'id_str': '1080298656928952320',
#   'text': 'Test',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="https://siwictyas.cf" rel="nofollow">siwi.c</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
# ...

# %%
scores = result['scores']['universal']
scores
# Out:
# 0.037980136466376074

# %%
if(scores < 0.5):
    print(user+" : human")
else :
    print(user+" : bot")
# Out:
# @afarihas : human

# %%
# Check a sequence of accounts
accounts = ['@clayadavis', '@onurvarol', '@afarihas']
scores = []
for screen_name, result in bom.check_accounts_in(accounts):
#     print(result['scores']['english']*100)
    scores = result['scores']['english']*100
    if(scores<10):
        print(screen_name+" is human with score "+str(scores))
    else:
        print(screen_name+" is bot with score "+str(scores))
# Out:
# @clayadavis is bot with score 75.65854729457973
# @onurvarol is bot with score 12.588928944948307
# @afarihas is human with score 2.3437100509770628

# %%
scores
# Out:
# {'english': 0.10030935716061677, 'universal': 0.18207903130928815}

# %%
# https://towardsdatascience.com/visualisation-of-information-from-raw-twitter-data-part-2-11707a65e920

# %%
usertweets = tweets.groupby('Username')
#Taking the top 25 tweeting users
top_users = usertweets.count()['text'].sort_values(ascending = False)[:25]
top_users_dict = top_users.to_dict()
user_ordered_dict =sorted(top_users_dict.items(), key=lambda x:x[1])
user_ordered_dict = user_ordered_dict[::-1]
#Now, like in the previous hashtags and mention cases, going to make #two lists, one with the username and one with the value
dict_values = []
dict_keys = []
for item in user_ordered_dict[0:25]:
    dict_keys.append(item[0])
    dict_values.append(item[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-e2a2982e4b23> in <module>
# ----> 1 usertweets = tweets.groupby('Username')
#       2 #Taking the top 25 tweeting users
#       3 top_users = usertweets.count()['text'].sort_values(ascending = False)[:25]
#       4 top_users_dict = top_users.to_dict()
#       5 user_ordered_dict =sorted(top_users_dict.items(), key=lambda x:x[1])
#
# NameError: name 'tweets' is not defined

# %%
#Connecting to the botometer API
bom = botometer.Botometer(wait_on_ratelimit = True, mashape_key = rapidapi_key, **twitter_app_auth)
#Returns a dictionary with the most active users and the porcentage #of likeliness of them bein a Bot using botometer
bot_dict = {}
top_users_list = dict_keys
for user in top_users_list:
    user = '@'+ user
    try:
        result = bom.check_account(user)
        bot_dict[user] = int((result['scores']['english'])*100)
    except tweepy.TweepError:
        bot_dict[user] = 'None'
        continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-05c091bf7689> in <module>
#       3 #Returns a dictionary with the most active users and the porcentage #of likeliness of them bein a Bot using botometer
#       4 bot_dict = {}
# ----> 5 top_users_list = dict_keys
#       6 for user in top_users_list:
#       7     user = '@'+ user
#
# NameError: name 'dict_keys' is not defined

# %%
if(result['scores'])

# %%
import csv
csvFile = open("Bot_Analysis.csv", "a", encoding="utf-8")
csvWriter = csv.writer(csvFile)

# %%
header = ['tanggal','tweet','rt_count','fav_count',
          'username','scree_name', 'location', 'geo_enabled', 'friends', 'followers', 'statuteses_count', 'default_profil_img'
          'scores']
csvWriter.writerow(header)

# %%
user = []
scores = []
q = ['corona','covid']
for tweet in tweepy.Cursor(api.search, q=q, lang="id", since="2020-05-02", until="2020-05-03", rpp=100).items(1000):
    user = '@'+tweet.user.screen_name
    tw = tweet.text
    tw = unicodedata.normalize('NFKD', tw).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    tw = re.sub('([@#][\\w_-]+)',' ',tw)
    tw = re.sub(r'http\S+',' ',tw)
    tw = re.sub(r'[^\w\s]',' ',tw)
    tw = re.sub('RT|cc', '', tw)
    tw = re.sub(r'(.)\\1{2,}', r'\\1', tw)
    tw = re.sub(r'\\b[a-zA-Z]\\b', ' ', tw)
    tw = re.sub('[\\s]+', ' ', tw)
    tw = tw.lower()
    print(tw)
    csvWriter.writerow([tweet.created_at, tw, tweet.retweet_count, tweet.favorite_count, user, tweet.user.name, tweet.user.location, tweet.user.geo_enabled, tweet.user.friends_count, tweet.user.followers_count, tweet.user.statuses_count, tweet.user.default_profile_image])
# Out:
#  alhamdulillah obat anti virus corona covid 19 telah disahkan remdesivir approved as drug of choice for covid 19
#  untuk bayar hotel para petugas medis sbg garda terdepan melawan corona aja gak mampu sampai mereka harus
#  untuk bayar hotel para petugas medis sbg garda terdepan melawan corona aja gak mampu sampai mereka harus
#  semoga covid menghancurkan ekonomi indonesia khusus para pebisnis fintech
#  wacyigelinta cudurka corona fariin muuqaal ah oo xoojinaysa kahortagga cudurka covid 19
#  semoga covid menghancurkan ekonomi indonesia khusus para pebisnis fintech pinjol kredi
#  nadiem makarim menolak teori konspirasi terkait virus corona covid 19 secara psikologis nadiem mengatakan pemikiran itu ad
#  alhamdulillah obat anti virus corona covid 19 telah disahkan remdesivir approved as drug of choice for covid 19
#  vaksin covid 19 sedang menunggu hasil uji klinis utk di sahkan
# ...

# %%
df = pd.read_csv('Bot_Analysis.csv', encoding = "ISO-8859-1")
username = df['username']
username

# %%
# Check a sequence of accounts
scores = []
for screen_name, result in bom.check_accounts_in(user):
#     print(result['scores']['english']*100)
    scores = result['scores']['english']*100
    print(scores)

# %%
#REFERENCE
https://github.com/shruti-cs/TwitterBotDetectionAndClassification/blob/master/botornot_3.py

# %%
df = pd.read_csv("Bot_Analysis_Clean.csv",engine="python")
tweet = df["tweet"]
username = df["username"]
skor = df["scores"]

# %%
# accounts = ['@clayadavis', '@onurvarol', '@afarihas']

for screen_name, result in bom.check_accounts_in(username):
#     print(result['scores']['english']*100)
    skor = result['scores']['english']*100
    if(scores<10):
        print(screen_name+" is human with score "+str(scores))
    else:
        print(screen_name+" is bot with score "+str(scores))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-148-2e37b4c61f8f> in <module>
#       1 # accounts = ['@clayadavis', '@onurvarol', '@afarihas']
#       2
# ----> 3 for screen_name, result in bom.check_accounts_in(username):
#       4 #     print(result['scores']['english']*100)
#       5     skor = result['scores']['english']*100
#
# ~\anaconda3\lib\site-packages\botometer\__init__.py in check_accounts_in(self, accounts, full_user_object, on_error, **kwargs)
#     148                 try:
#     149                     result = sub_instance.check_account(
# --> 150                         account, full_user_object=full_user_object)
#     151                 except (TweepError, NoTimelineError) as e:
#     152                     err_msg = '{}: {}'.format(
#
# ~\anaconda3\lib\site-packages\botometer\__init__.py in check_account(self, user, full_user_object)
# ...
